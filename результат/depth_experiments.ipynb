# %% [markdown]
# # Реультаты первого задания

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', 'utils'))
import depth_experiments

# %% [markdown]
# # Лучшая глубина для MNIST
#
# Где больше всего Test Accuracy

# %%
depth_experiments.define_best_depth_mnist()
# Out:
# Лучшая глубина для MNIST: 3_layers

# %% [markdown]
# # Лучшая глубина для CIFAR
#
# Где больше всего Test Accuracy

# %%
depth_experiments.define_best_depth_cifar()
# Out:
# Лучшая глубина для CIFAR: 5_layers

# %% [markdown]
# # Сравнение обычных моделей, с droput и c batchNorm на MNIST
#
# - Лучший Test Accuracy у базовых и у BatchNorm моделей
# - Базовые модели обучаются быстрее всеx. Dropout модели дольше всеx
# - Реже с переобучением сталкиваются базовые модели. Droput и batchNorm - одинакого

# %%
depth_experiments.compare_models_on_mnist()

# %% [markdown]
# # Сравнение обычных моделей, с droput и c batchnorm на CIFAR
#
# - Лучший Test Accuracy у BatchNorm моделей
# - Базовые модели обучаются быстрее всеx. BatchNorm модели дольше всеx
# - Dropout модели не сталкивались с переобучением. Чаще всего переобучались BatchNorm модели

# %%
depth_experiments.compare_models_on_cifar()

# %% [markdown]
# # Когда и на каких моделях начиналось переобучение на MNIST
#
#
# Отображены эпохи, когда падал Test Accuracy и увеличивался Test Loss

# %%
depth_experiments.define_retraining_mnist()
# Out:
# Переобучение модели 1_layer на датасете MNIST началось на 5 эпохе
# Переобучение модели 2_layers на датасете MNIST началось на 5 эпохе
# Переобучение модели 1_layer_dropout на датасете MNIST началось на 4 эпохе
# Переобучение модели 2_layers_dropout на датасете MNIST началось на 4 эпохе
# Переобучение модели 7_layers_dropout на датасете MNIST началось на 5 эпохе
# Переобучение модели 1_layer_batchnorm на датасете MNIST началось на 5 эпохе
# Переобучение модели 3_layers_batchnorm на датасете MNIST началось на 4 эпохе
# Переобучение модели 7_layers_batchnorm на датасете MNIST началось на 4 эпохе

# %% [markdown]
# # Когда и на каких моделях начиналось переобучение на CIFAR
#
#
# Отображены эпохи, когда падал Test Accuracy и увеличивался Test Loss

# %%
depth_experiments.define_retraining_cifar()
# Out:
# Переобучение модели 1_layer на датасете CIFAR началось на 5 эпохе
# Переобучение модели 2_layers на датасете CIFAR началось на 5 эпохе
# Переобучение модели 1_layer_batchnorm на датасете CIFAR началось на 3 эпохе
# Переобучение модели 2_layers_batchnorm на датасете CIFAR началось на 5 эпохе
# Переобучение модели 5_layers_batchnorm на датасете CIFAR началось на 5 эпохе
