# %% [markdown]
# # Результаты второго задания

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', 'utils'))
import width_experiments

# %% [markdown]
# # Сравнение точности и времени обучения по категориям ширины слоёв
#
# - узкие слои сильно уступают остальным категориям в точности
# - Очень широкие слои обучаются дольше остальных

# %%
width_experiments.compare_accuracy_and_time()

# %% [markdown]
# # Сравнение количества параметров по категориям ширины слоёв
#
# - кол-во параметров растёт экспоненционально
# - чем больше параметров - тем выше итоговая Test Accuracy, но дольше время обучения

# %%
width_experiments.compare_parameters_count()

# %% [markdown]
# # Лучшая конфигурация модели, наденная с помощью grid search:
# - 3_layers_xwide_constant_batchnorm

# %% [markdown]
# # конфигурации моделей в виде heatmap
# - в Test Accueracy сильно по сравненисю с другими проседают конфигурации с узкими увеличивающимися слоями
# - большой dropout (0.4) заметно негативно влияет на Test Accuracy. Лучшие показатели без dropout

# %%
width_experiments.display_all_models()
